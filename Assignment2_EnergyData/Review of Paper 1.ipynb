# %% [markdown]
# # Research Paper 1 Summary

# %% [markdown]
# This research deals with the understanding of the energy consumption of appliances in domestic homes which accounts for almost 20-30% energy consumption. Thus, prediction models of electrical energy consumption in buildings can be useful for a number of applications such as to determine adequate sizing of photovoltaics and energy storage to diminish power flow into the grid, to detect abnormal energy use patterns, to be part of an energy management system for load control, to model predictive control applications where the loads are needed , for demand side management and demand side response and as an input for building performance simulation analysis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Appliances such as refrigerators have a uniform load profile while the load profile of appliances such as clothes washer, clothes dryer have very user dependent and vary from household to household. From conducting various research over the years, it was concluded that the most important variables were weather, location, and floor area.

# %% [markdown]
# This paper explores several questions. Is the weather data obtained from a nearby weather station representative enough to improve the appliances energy consumption prediction? Can the temperature and humidity measurements from a wireless network help in the energy prediction? From all the data used in prediction models, which parameters are the most important in energy prediction? Since occupancy has a direct effect on the appliances use, what impact does the inclusion of a sub metered energy measurement related to occupancy (light) have on the prediction?

# %% [markdown]
# The electric consumption of a house located in Stambruges was recorded by M-BUS energy counters at 10 min intervals for this research so as to find quick changes in energy consumption, the energy information is collected with an internet-connected energy monitoring system where it is stored and then it is reported by e-mail every 12 h. The low energy house was designed according to the passive house certification. For this certification, the building was designed to have an annual heating load and cooling load of no more than 15 kWh/m2 per year according to the Passive House Planning Package (PHPP) software design tool. It is important to note that a wood chimney provides most of the heating load in the house. The total kg amount and type of wood has been manually logged monthly. Other important factors that have been emphasized in this research relate to the heat generated on usage of these appliances which in turn are recorded by sensors placed in all the rooms throughout the house which can measure humidity, pressure and temperature and thus give us an idea as to the occupation level of a room, also weather data from a nearby weather station has been added to the data and thus help in predicting the energy needs accordingly, light energy consumption accounts for around 1-4% as led lights were used, also the house has 4 occupants, 2 adults and 2 teenagers.

# %% [markdown]
# Following graphs show the Appliances energy consumption measurement for the whole period and the first week:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The combined data set is split in training and test validation using CARET'S create data partition function. 75% of the data is used for the training of the models and the rest is used for testing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This figure is a pair plot which shows the Corelations between the energy consumption of appliances with all the other recorded variables.
# From studying this pair plot we can analyse which variables affect the energy consumption in either a postive or negative way.

# %% [markdown]
# Next it was desireable to fond out which parameters are important and which parameters do nbot improve the prediction of the energy consumption, for this the Boruta package was used to select all relevant variables.

# %% [markdown]
# The analysis in this research has been done using four regression models namely Multiple Linear Regression Model, SVM-radial Model, Random Forest and GBM models with different combination of predictors and to find out and compare the performance of each of the regression models the values(performance evaluation indices) of RMSE, R-Squared, MAE and MAPE were found out. The best model will be the one that has the lowest RMSE and highest R-Squared values, so on camaparing the models it was found that the Random Forest and GBM models had very simlar performance based on their RMSE and R-squared values and confidence intervals. So, it was found that the GBM and RF models improve the RMSE and R-Squared predictions as compared to the SVM and Miltiple linear regressionear  models.

# %% [markdown]
# Furthermore, the weather data from the nearby weather station was shown to increase the prediction accuracy in the GBM models. The GBM models with only weather data ranked the pressure as the most important weather variable which might be due to its influence on the wind speed and higher rainfall probability which could potentially increase the occupancy of the house. This study has found curious relationships between variables.
